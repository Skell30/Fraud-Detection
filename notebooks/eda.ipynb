# %%
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns 
import ipaddress
import socket
import struct

# %%
fraud=pd.read_csv(r"C:\Users\pc\Fraud-Detection\data\fraud_cleaned.csv")
credit=pd.read_csv(r"C:\Users\pc\Fraud-Detection\data\credit_clean.csv")
ip=pd.read_csv(r'C:\Users\pc\Fraud-Detection\data\ip_clean.csv')

# %%
plt.figure(figsize=(6,4))
sns.histplot(fraud['age'], kde=True, bins=30)
plt.title("Age Distribution")
plt.show()

# %%
sns.countplot(data=fraud, x='sex')
plt.title("Transaction By Age")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=fraud, x='browser', order=fraud['browser'].value_counts().index)
plt.title("Transaction By Browser")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=fraud, x='class')
plt.title("fraud count")
plt.show()

# %%
sns.boxplot(data=fraud, x="class", y='age')
plt.title("Age vs Fraud")
plt.show()

# %%
sns.boxplot(data=fraud, x='class', y='purchase_value')
plt.title('purchase value vs fraud')
plt.show()

# %%
fraud.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0
